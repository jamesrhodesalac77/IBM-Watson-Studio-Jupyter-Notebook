# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **James Rhode E. Salac**
# Data Scientist

# %% [markdown]
# *I'm interested in data science because I'm fascinated wit how data science can find solutions to seemingly intractable problems. Finding patterns and insights from unstructured data can be challenging but it can also be quit rewarding.*

# %% [markdown]
# ### the code in cell 5 will print a well-known pangram ###

# %%
print("The quick brown fox jumps over the lazy dog")
# Out:
# The quick brown fox jumps over the lazy dog

# %% [markdown]
# #### Type of iris flowers (bulleted list)
# -  Setosa
# -  Virginica
# -  Versicolor
#
# #### Type of iris flowers (numbered list)
# 1. Setosa
# 2. Virginica
# 3. Versicolor
#
# __[link text](http://url)__
